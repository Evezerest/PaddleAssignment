# %% [markdown]
# # PP-Tracking之手把手玩转多目标跟踪
#
# **PP-Tracking**是基于飞桨深度学习框架的业界首个开源实时跟踪系统。针对实际业务的难点痛点，PP-Tracking内置行人车辆跟踪、跨镜头跟踪、多类别跟踪、小目标跟踪及流量计数等能力与产业应用，同时提供可视化开发界面。模型集成多目标跟踪，目标检测，ReID轻量级算法，进一步提升PP-Tracking在服务器端部署性能。同时支持python，C++部署，适配Linux，Nvidia Jetson多平台环境。
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/c8ffcde8c1974a69863806e3aeaf81c6680f3a8de50d4d56be9a14f155979f9e)
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/ad76397a0c954b86b024a4330343e073e8ad0c1261da4a29be2a0f3bdbb196c6)
# ![](https://ai-studio-static-online.cdn.bcebos.com/38c90f74410041a3964e4f52b98f3ee881b443b6c7264f6ebd063b3c03ff8e4c)
#
#
# 在如下示例中，将介绍如何使用示例代码基于您在BML中已创建的数据集来完成单镜头跟踪模型的训练，评估和推理。以及多镜头的部署。

# %% [markdown]
# # 环境准备
# 下载PaddleDetection并且安装环境requirements

# %%
# !tar xvf PaddleDetection.tar

# %%
# Download PaddleDetection
#!git clone https://gitee.com/paddlepaddle/PaddleDetection.git -b develop

# %%
# !pip install --upgrade pip -i https://mirror.baidu.com/pypi/simple
# !pip install paddlepaddle-gpu==2.2.0rc0.post101 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html -i https://mirror.baidu.com/pypi/simple
# !cd PaddleDetection/ && pip install pycocotools && pip install -r requirements.txt && python setup.py install
# Out:
# Finished processing dependencies for paddledet==2.3.0

# %% [markdown]
# # 数据集准备
#
# MOT16数据集：MOT16数据集是在2016年提出来的用于衡量多目标跟踪检测和跟踪方法标准的数据集，专门用于行人跟踪。官网地址是：https://motchallenge.net/
#
# det.txt
# 这个文件中存储了图片的检测框的信息(检测得到的信息文件)，部分内容展示如下：
#
# ```
# 1,-1,1359.1,413.27,120.26,362.77,2.3092,-1,-1,-1
# 1,-1,571.03,402.13,104.56,315.68,1.5028,-1,-1,-1
# ```
# 从左到右分别代表：
# * frame: 第几帧图片
# * id: 这个检测框分配的id，在这里都是-1代表没有id信息
# * bbox(四位): 分别是左上角坐标和长宽
# * conf：这个bbox包含物体的置信度，可以看到并不是传统意义的0-1，分数越高代表置信度越高
# * MOT3D(x,y,z): 是在MOT3D中使用到的内容，这里关心的是MOT2D，所以都设置为-1
#
#
# #### 修改mot的配置文件，文件目录如下
# 整理之前：
# ```
# MOT16
#   └——————train
#   └——————test
#
# 整理之后：
# MOT16
#    |——————images
#    |        └——————train
#    |        └——————test
#    └——————labels_with_ids
#             └——————train
# ```
#
# 详细参考[MOT数据准备文档](https://github.com/PaddlePaddle/PaddleDetection/blob/develop/docs/tutorials/PrepareMOTDataSet_cn.md)

# %%
# 网速不好可以自行下载上传,解压
# !cd ./data && wget https://bj.bcebos.com/v1/paddledet/data/mot/demo/MOT16.zip
# !mv ./data/MOT16.zip ./PaddleDetection/dataset/mot
# !cd ./PaddleDetection/dataset/mot && unzip MOT16.zip
# 生成labels_with_ids
# !cd ./PaddleDetection/dataset/mot/MOT16 && mkdir -p images
# !cd ./PaddleDetection/dataset/mot/MOT16 && mv ./train ./images && mv ./test ./images
# !cd ./PaddleDetection/dataset/mot && python gen_labels_MOT.py
# 生成mot16.train文件并且复制到 image_lists下面
import glob
import os.path as osp
image_list = []
for seq in sorted(glob.glob('PaddleDetection/dataset/mot/MOT16/images/train/*')):
    for image in glob.glob(osp.join(seq, "img1")+'/*.jpg'):
        image = image.replace('PaddleDetection/dataset/mot/','')
        image_list.append(image)
with open('mot16.train','w') as image_list_file:
    image_list_file.write(str.join('\n',image_list))

# !mkdir -p ./PaddleDetection/dataset/mot/image_lists && cp -r mot16.train ./PaddleDetection/dataset/mot/image_lists
# Out:
#   inflating: MOT16/train/MOT16-02/seqinfo.ini

# %% [markdown]
# # step 1
# #### 修改配置文件里面的数据集
# 添加在PaddleDetection/configs/mot/fairmot/fairmot_dla34_30e_1088x608.yml文件最后
#
# ```
# ... ...
# # for MOT training
# # for MOT training
# TrainDataset:
#   !MOTDataSet
#     dataset_dir: dataset/mot
#     image_lists: ['mot16.train']
#     data_fields: ['image', 'gt_bbox', 'gt_class', 'gt_ide']
#
# # for MOT evaluation
# # If you want to change the MOT evaluation dataset, please modify 'data_root'
# EvalMOTDataset:
#   !MOTImageFolder
#     dataset_dir: dataset/mot
#     data_root: MOT16/images/train
#     keep_ori_im: False # set True if save visualization images or video, or used in DeepSORT
#
# # for MOT video inference
# TestMOTDataset:
#   !MOTImageFolder
#     dataset_dir: dataset/mot
#     keep_ori_im: True # set True if save visualization images or video
#  ```

# %% [markdown]
# # step 2
# #### 开始训练
#
# 使用MOT16-02序列作为训练数据，训练30epoch，V100环境下大约需要30分钟

# %%
# !cd PaddleDetection/ && python -m paddle.distributed.launch --log_dir=./fairmot_dla34_30e_1088x608/ --gpus 0 tools/train.py -c configs/mot/fairmot/fairmot_dla34_30e_1088x608.yml
# Out:
# -----------  Configuration Arguments -----------
# elastic_server: None
# force: False
# gpus: 0
# heter_worker_num: None
# heter_workers:
# host: None
# http_port: None
# ips: 127.0.0.1
# job_id: None
# log_dir: ./fairmot_dla34_30e_1088x608/
# np: None
# nproc_per_node: None
# run_mode: None
# scale: 0
# server_num: None
# servers:
# training_script: tools/train.py
# training_script_args: ['-c', 'configs/mot/fairmot/fairmot_dla34_30e_1088x608.yml']
# worker_num: None
# workers:
# ------------------------------------------------
# WARNING 2022-01-07 16:51:28,232 launch.py:381] Not found distinct arguments and compiled with cuda or xpu. Default use collective mode
# launch train in GPU mode!
# INFO 2022-01-07 16:51:28,236 launch_utils.py:525] Local start 1 processes. First process distributed environment info (Only For Debug):
#     +=======================================================================================+
#     |                        Distributed Envs                      Value                    |
#     +---------------------------------------------------------------------------------------+
#     |                       PADDLE_TRAINER_ID                        0                      |
#     |                 PADDLE_CURRENT_ENDPOINT                 127.0.0.1:42088               |
#     |                     PADDLE_TRAINERS_NUM                        1                      |
#     |                PADDLE_TRAINER_ENDPOINTS                 127.0.0.1:42088               |
#     |                     PADDLE_RANK_IN_NODE                        0                      |
#     |                 PADDLE_LOCAL_DEVICE_IDS                        0                      |
#     |                 PADDLE_WORLD_DEVICE_IDS                        0                      |
#  72%|███████▏  | 92077/127930 [00:02<00:00, 41243.35KB/s]
#  76%|███████▌  | 96867/127930 [00:02<00:00, 43037.03KB/s]
#  80%|███████▉  | 101841/127930 [00:02<00:00, 44849.00KB/s]
#  84%|████████▎ | 106931/127930 [00:02<00:00, 46504.02KB/s]
#  88%|████████▊ | 112073/127930 [00:03<00:00, 47875.72KB/s]
#  92%|█████████▏| 117379/127930 [00:03<00:00, 49249.56KB/s]
#  96%|█████████▌| 122416/127930 [00:03<00:00, 49579.67KB/s]
# 100%|█████████▉| 127401/127930 [00:03<00:00, 48745.60KB/s]
# 100%|██████████| 127930/127930 [00:03<00:00, 38217.80KB/s]
# [01/07 16:51:41] ppdet.utils.checkpoint INFO: The shape [14455] in pretrained weight reid.classifier.bias is unmatched with the shape [56] in model reid.classifier.bias. And the weight reid.classifier.bias will not be loaded
# [01/07 16:51:41] ppdet.utils.checkpoint INFO: The shape [128, 14455] in pretrained weight reid.classifier.weight is unmatched with the shape [128, 56] in model reid.classifier.weight. And the weight reid.classifier.weight will not be loaded
# [01/07 16:51:41] ppdet.utils.checkpoint INFO: Finish loading model weights: /home/aistudio/.cache/paddle/weights/fairmot_dla34_crowdhuman_pretrained.pdparams
# [01/07 16:51:42] ppdet.engine INFO: Epoch: [0] [  0/100] learning_rate: 0.000100 loss: 8.975628 heatmap_loss: 1.026012 size_loss: 0.720102 offset_loss: 0.227525 det_loss: 1.325547 reid_loss: 4.346581 eta: 0:31:56 batch_cost: 0.6389 data_cost: 0.0004 ips: 9.3909 images/s
# [01/07 16:51:54] ppdet.engine INFO: Epoch: [0] [ 20/100] learning_rate: 0.000100 loss: 7.351644 heatmap_loss: 0.875994 size_loss: 0.607072 offset_loss: 0.217225 det_loss: 1.149532 reid_loss: 3.647079 eta: 0:30:07 batch_cost: 0.6048 data_cost: 0.0003 ips: 9.9199 images/s
# [01/07 16:52:06] ppdet.engine INFO: Epoch: [0] [ 40/100] learning_rate: 0.000100 loss: 6.459711 heatmap_loss: 0.777951 size_loss: 0.584243 offset_loss: 0.214595 det_loss: 1.061100 reid_loss: 3.203158 eta: 0:29:52 batch_cost: 0.6048 data_cost: 0.0003 ips: 9.9201 images/s
# [01/07 16:52:18] ppdet.engine INFO: Epoch: [0] [ 60/100] learning_rate: 0.000100 loss: 5.716257 heatmap_loss: 0.720933 size_loss: 0.496798 offset_loss: 0.211445 det_loss: 0.985260 reid_loss: 2.880067 eta: 0:29:41 batch_cost: 0.6061 data_cost: 0.0003 ips: 9.8988 images/s
# [01/07 16:52:30] ppdet.engine INFO: Epoch: [0] [ 80/100] learning_rate: 0.000100 loss: 5.379826 heatmap_loss: 0.691431 size_loss: 0.455542 offset_loss: 0.208904 det_loss: 0.940998 reid_loss: 2.691281 eta: 0:29:29 batch_cost: 0.6064 data_cost: 0.0003 ips: 9.8940 images/s
# [01/07 16:52:43] ppdet.utils.checkpoint INFO: Save checkpoint: output/fairmot_dla34_30e_1088x608
# [01/07 16
# [01/07 16:58:38] ppdet.engine INFO: Epoch: [6] [ 60/100] learning_rate: 0.000100 loss: 1.584901 heatmap_loss: 0.441508 size_loss: 0.391775 offset_loss: 0.187986 det_loss: 0.667876 reid_loss: 0.693563 eta: 0:23:56 batch_cost: 0.6126 data_cost: 0.0003 ips: 9.7937 images/s
# [01/07 16:58:50] ppdet.engine INFO: Epoch: [6] [ 80/100] learning_rate: 0.000100 loss: 1.540609 heatmap_loss: 0.423336 size_loss: 0.381998 offset_loss: 0.190406 det_loss: 0.657609 reid_loss: 0.693853 eta: 0:23:44 batch_cost: 0.6133 data_cost: 0.0003 ips: 9.7833 images/s
# [01/07 16:59:04] ppdet.utils.checkpoint INFO: Save checkpoint: output/fairmot_dla34_30e_1088x608
# [01/07 16:59:05] ppdet.engine INFO: Epoch: [7] [  0/100] learning_rate: 0.000100 loss: 1.597570 heatmap_loss: 0.452383 size_loss: 0.411301 offset_loss: 0.190137 det_loss: 0.686212 reid_loss: 0.706079 eta: 0:23:32 batch_cost: 0.6236 data_cost: 0.0075 ips: 9.6222 images/s
# [01/07 16:59:17] ppdet.engine INFO: Epoch: [7] [ 20/100] learning_rate: 0.000100 loss: 1.578642 heatmap_loss: 0.444902 size_loss: 0.398266 offset_loss: 0.192446 det_loss: 0.686170 reid_loss: 0.671844 eta: 0:23:20 batch_cost: 0.6192 data_cost: 0.0003 ips: 9.6893 images/s
# [01/07 16:59:29] ppdet.engine INFO: Epoch: [7] [ 40/100] learning_rate: 0.000100 loss: 1.522570 heatmap_loss: 0.449996 size_loss: 0.410848 offset_loss: 0.190203 det_loss: 0.676004 reid_loss: 0.656149 eta: 0:23:08 batch_cost: 0.6140 data_cost: 0.0005 ips: 9.7728 images/s
# [01/07 16:59:42] ppdet.engine INFO: Epoch: [7] [ 60/100] learning_rate: 0.000100 loss: 1.424796 heatmap_loss: 0.424600 size_loss: 0.385220 offset_loss: 0.190352 det_loss: 0.649187 reid_loss: 0.631036 eta: 0:22:55 batch_cost: 0.6141 data_cost: 0.0003 ips: 9.7697 images/s
# [01/07 16:59:54] ppdet.engine INFO: Epoch: [7] [ 80/100] learning_rate: 0.000100 loss: 1.382294 heatmap_loss: 0.415107 size_loss: 0.377758 offset_loss: 0.188869 det_loss: 0.641550 reid_loss: 0.619592 eta: 0:22:43 batch_cost: 0.6133 data_cost: 0.0003 ips: 9.7834 images/s
# [01/07 17:00:07] ppdet.utils.checkpoint INFO: Save checkpoint: output/fairmot_dla34_30e_1088x608
# [01/07 17:00:08] ppdet.engine INFO: Epoch: [8] [  0/100] learning_rate: 0.000100 loss: 1.438855 heatmap_loss: 0.433298 size_loss: 0.385539 offset_loss: 0.192284 det_loss: 0.668669 reid_loss: 0.610710 eta: 0:22:32 batch_cost: 0.6272 data_cost: 0.0098 ips: 9.5670 images/s
# ^C
# WARNING 2022-01-07 17:00:13,311 launch.py:292] Terminating... exit
# INFO 2022-01-07 17:00:13,311 launch_utils.py:317] terminate process group gid:730

# %% [markdown]
# # step3
# #### 开始评估
# 为了方便我们下载训练好的模型进行eval
# https://paddledet.bj.bcebos.com/models/mot/fairmot_dla34_30e_1088x608.pdparams

# %%
# download model.pdparams and put it into `output` directory
# !mkdir -p PaddleDetection/output && cd PaddleDetection/output/ && wget https://bj.bcebos.com/v1/paddledet/models/mot/fairmot_dla34_30e_1088x608.pdparams 
# !cd PaddleDetection && CUDA_VISIBLE_DEVICES=0 python tools/eval_mot.py -c configs/mot/fairmot/fairmot_dla34_30e_1088x608.yml -o weights=output/fairmot_dla34_30e_1088x608.pdparams
# Out:
# --2022-01-07 17:00:19--  https://bj.bcebos.com/v1/paddledet/models/mot/fairmot_dla34_30e_1088x608.pdparams
# Resolving bj.bcebos.com (bj.bcebos.com)... 182.61.200.195, 182.61.200.229, 2409:8c04:1001:1002:0:ff:b001:368a
# Connecting to bj.bcebos.com (bj.bcebos.com)|182.61.200.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 130895015 (125M) [application/octet-stream]
# Saving to: ‘fairmot_dla34_30e_1088x608.pdparams’
#
# fairmot_dla34_30e_1 100%[===================>] 124.83M  31.6MB/s    in 4.0s
#
# 2022-01-07 17:00:23 (30.9 MB/s) - ‘fairmot_dla34_30e_1088x608.pdparams’ saved [130895015/130895015]
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/tensor/creation.py:130: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if data.dtype == np.object:
# W0107 17:00:27.249848  2049 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W0107 17:00:27.255285  2049 device_context.cc:465] device: 0, cuDNN Version: 7.6.
# [01/07 17:00:30] ppdet.utils.checkpoint INFO: Finish resuming model weights: output/fairmot_dla34_30e_1088x608.pdparams
# [01/07 17:00:30] ppdet.engine.tracker INFO: start seq: MOT16-02
# [01/07 17:00:30] ppdet.engine.tracker INFO: Found 600 inference images in total.
# [01/07 17:00:31] ppdet.engine.tracker INFO: Processing frame 0 (100000.00 fps)
# [01/07 17:00:33] ppdet.engine.tracker INFO: Processing frame 40 (19.68 fps)
# [01/07 17:00:35] ppdet.engine.tracker INFO: Processing frame 80 (20.10 fps)
# [01/07 17:00:37] ppdet.engine.tracker INFO: Processing frame 120 (19.73 fps)
# [01/07 17:00:39] ppdet.engine.tracker INFO: Processing frame 160 (19.67 fps)
# [01/07 17:00:42] ppdet.engine.tracker INFO: Processing frame 200 (19.64 fps)
# [01/07 17:00:44] ppdet.engine.tracker INFO: Processing frame 240 (19.66 fps)
# [01/07 17:00:46] ppdet.engine.tracker INFO: Processing frame 280 (19.62 fps)
# [01/07 17:00:48] ppdet.engine.tracker INFO: Processing frame 320 (19.57 fps)
# [01/07 17:00:50] ppdet.engine.tracker INFO: Processing frame 360 (19.43 fps)
# [01/07 17:00:52] ppdet.engine.tracker INFO: Processing frame 400 (19.40 fps)
# [01/07 17:00:54] ppdet.engine.tracker INFO: Processing frame 440 (19.42 fps)
# [01/07 17:00:57] ppdet.engine.tracker INFO: Processing frame 480 (19.45 fps)
# [01/07 17:00:59] ppdet.engine.tracker INFO: Processing frame 520 (19.34 fps)
# [01/07 17:01:01] ppdet.engine.tracker INFO: Processing frame 560 (19.16 fps)
# MOT results save in output/mot_results/MOT16-02.txt
# [01/07 17:01:03] ppdet.engine.tracker INFO: Evaluate seq: MOT16-02
# [01/07 17:01:04] ppdet.engine.tracker INFO: Time elapsed: 31.41 seconds, FPS: 19.10
# INFO:root:partials: 0.200 seconds.
# INFO:root:mergeOverall: 0.203 seconds.
#           IDF1   IDP   IDR  Rcll  Prcn GT MT PT ML  FP   FN IDs   FM  MOTA  MOTP IDt IDa IDm
# MOT16-02 62.6% 72.3% 55.2% 71.8% 94.0% 54 21 30  3 824 5035 155  531 66.3% 0.200  83  40  10
# OVERALL  62.6% 72.3% 55.2% 71.8% 94.0% 54 21 30  3 824 5035 155  531 66.3% 0.200  83  40  10

# %% [markdown]
# # step 4
# #### 开始推理
# 使用下载好的模型进行推理，为了方便我们只推理了`dataset/mot/MOT16/images/test/MOT16-01/img1`下面的数据
#
# 跟踪输出视频保存在`output/mot_outputs/img1_vis.mp4`
#
# txt文件结果保存在`output/mot_results/img1.txt`,输出格式表示为frame_id, id, bbox_left, bbox_top, bbox_width, bbox_height, score, x, y, z

# %%
# !cd PaddleDetection/ && CUDA_VISIBLE_DEVICES=0 python tools/infer_mot.py -c configs/mot/fairmot/fairmot_dla34_30e_1088x608.yml -o weights=output/fairmot_dla34_30e_1088x608.pdparams --image_dir=dataset/mot/MOT16/images/test/MOT16-01/img1  --save_videos
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/tensor/creation.py:130: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if data.dtype == np.object:
# W0107 17:01:31.576774  2159 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W0107 17:01:31.582242  2159 device_context.cc:465] device: 0, cuDNN Version: 7.6.
# [01/07 17:01:35] ppdet.utils.checkpoint INFO: Finish resuming model weights: output/fairmot_dla34_30e_1088x608.pdparams
# [01/07 17:01:35] ppdet.engine.tracker INFO: Starting tracking folder dataset/mot/MOT16/images/test/MOT16-01/img1, found 450 images
# [01/07 17:01:35] ppdet.engine.tracker INFO: Processing frame 0 (100000.00 fps)
# [01/07 17:01:39] ppdet.engine.tracker INFO: Processing frame 40 (20.38 fps)
# [01/07 17:01:42] ppdet.engine.tracker INFO: Processing frame 80 (20.54 fps)
# [01/07 17:01:46] ppdet.engine.tracker INFO: Processing frame 120 (20.76 fps)
# [01/07 17:01:49] ppdet.engine.tracker INFO: Processing frame 160 (20.83 fps)
# [01/07 17:01:53] ppdet.engine.tracker INFO: Processing frame 200 (20.85 fps)
# [01/07 17:01:56] ppdet.engine.tracker INFO: Processing frame 240 (20.93 fps)
# [01/07 17:01:59] ppdet.engine.tracker INFO: Processing frame 280 (20.99 fps)
# [01/07 17:02:03] ppdet.engine.tracker INFO: Processing frame 320 (20.82 fps)
# [01/07 17:02:07] ppdet.engine.tracker INFO: Processing frame 360 (20.73 fps)
# [01/07 17:02:10] ppdet.engine.tracker INFO: Processing frame 400 (20.73 fps)
# [01/07 17:02:14] ppdet.engine.tracker INFO: Processing frame 440 (20.72 fps)
# ffmpeg version 2.8.15-0ubuntu0.16.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 5.4.0 (Ubuntu 5.4.0-6ubuntu1~16.04.10) 20160609
#   configuration: --prefix=/usr --extra-version=0ubuntu0.16.04.1 --build-suffix=-ffmpeg --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --cc=cc --cxx=g++ --enable-gpl --enable-shared --disable-stripping --disable-decoder=libopenjpeg --disable-decoder=libschroedinger --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librtmp --enable-libschroedinger --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxvid --enable-libzvbi --enable-openal --enable-opengl --enable-x11grab --enable-libdc1394 --enable-libiec61883 --enable-libzmq --enable-frei0r --enable-libx264 --enable-libopencv
#   libavutil      54. 31.100 / 54. 31.100
#   libavcodec     56. 60.100 / 56. 60.100
#   libavformat    56. 40.101 / 56. 40.101
#   libavdevice    56.  4.100 / 56.  4.100
#   libavfilter     5. 40.101 /  5. 40.101
#   libavresample   2.  1.  0 /  2.  1.  0
#   libswscale      3.  1.101 /  3.  1.101
#   libswresample   1.  2.101 /  1.  2.101
#   libpostproc    53.  3.100 / 53.  3.100
# [mjpeg @ 0x24c6660] Changeing bps to 8
# Input #0, image2, from 'output/mot_outputs/img1/%05d.jpg':
#   Duration: 00:00:18.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1920x1080 [SAR 1:1 DAR 16:9], 25 fps, 25 tbr, 25 tbn, 25 tbc
# No pixel format specified, yuvj420p for H.264 encoding chosen.
# Use -pix_fmt yuv420p for compatibility with outdated media players.
# [libx264 @ 0x24c9320] using SAR=1/1
# [libx264 @ 0x24c9320] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 AVX2 LZCNT BMI2
# [libx264 @ 0x24c9320] profile High, level 4.0
# [libx264 @ 0x24c9320] 264 - core 148 r2643 5c65704 - H.264/MPEG-4 AVC codec - Copyleft 2003-2015 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=34 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output/mot_outputs/img1/../img1_vis.mp4':
#   Metadata:
#     encoder         : Lavf56.40.101
#     Stream #0:0: Video: h264 (libx264) ([33][0][0][0] / 0x0021), yuvj420p(pc), 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc56.60.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# frame=  450 fps= 18 q=-1.0 Lsize=   18404kB time=00:00:17.92 bitrate=8413.3kbits/s
# video:18398kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.034301%
# [libx264 @ 0x24c9320] frame I:2     Avg QP:20.60  size:151352
# [libx264 @ 0x24c9320] frame P:176   Avg QP:22.31  size: 78156
# [libx264 @ 0x24c9320] frame B:272   Avg QP:26.51  size: 17575
# [libx264 @ 0x24c9320] consecutive B-frames:  3.6% 29.8% 53.3% 13.3%
# [libx264 @ 0x24c9320] mb I  I16..4: 14.7% 80.8%  4.6%
# [libx264 @ 0x24c9320] mb P  I16..4:  4.0% 27.1%  1.6%  P16..4: 21.0% 15.7% 14.7%  0.0%  0.0%    skip:16.0%
# [libx264 @ 0x24c9320] mb B  I16..4:  1.3%  6.4%  0.2%  B16..8: 32.8%  7.1%  1.8%  direct: 2.1%  skip:48.3%  L0:51.5% L1:39.5% BI: 9.0%
# [libx264 @ 0x24c9320] 8x8 transform intra:82.4% inter:87.3%
# [libx264 @ 0x24c9320] coded y,uvDC,uvAC intra: 62.2% 60.5% 3.5% inter: 20.4% 13.9% 2.4%
# [libx264 @ 0x24c9320] i16 v,h,dc,p: 36% 29% 35%  1%
# [libx264 @ 0x24c9320] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 24% 49%  2%  1%  1%  1%  1%  3%
# [libx264 @ 0x24c9320] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 45% 24% 12%  3%  3%  3%  4%  3%  3%
# [libx264 @ 0x24c9320] i8c dc,h,v,p: 37% 29% 32%  2%
# [libx264 @ 0x24c9320] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x24c9320] ref P L0: 53.6% 13.3% 19.7% 13.4%
# [libx264 @ 0x24c9320] ref B L0: 71.6% 22.1%  6.3%
# [libx264 @ 0x24c9320] ref B L1: 84.8% 15.2%
# [libx264 @ 0x24c9320] kb/s:8372.69
# [01/07 17:02:41] ppdet.engine.tracker INFO: Save video in output/mot_outputs/img1/../img1_vis.mp4
# MOT results save in output/mot_results/img1.txt

# %% [markdown]
# # step 5
# #### 导出模型

# %%
# !cd PaddleDetection && CUDA_VISIBLE_DEVICES=0 python tools/export_model.py -c configs/mot/fairmot/fairmot_dla34_30e_1088x608.yml -o weights=output/fairmot_dla34_30e_1088x608.pdparams
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/tensor/creation.py:130: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if data.dtype == np.object:
# [01/07 17:02:48] ppdet.utils.checkpoint INFO: Finish loading model weights: output/fairmot_dla34_30e_1088x608.pdparams
# [01/07 17:02:48] ppdet.engine INFO: Export inference config file to output_inference/fairmot_dla34_30e_1088x608/infer_cfg.yml
# W0107 17:02:51.943039  2357 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W0107 17:02:51.943104  2357 device_context.cc:465] device: 0, cuDNN Version: 7.6.
# [01/07 17:02:55] ppdet.engine INFO: Export model and saved in output_inference/fairmot_dla34_30e_1088x608

# %% [markdown]
# # step 6
# #### 使用导出的模型进行推理
#
# PP-Tracking中在部署阶段提供了多种跟踪相关功能，例如流量计数，出入口统计，绘制跟踪轨迹等，具体使用方法可以参考[文档](https://github.com/PaddlePaddle/PaddleDetection/tree/release/2.3/deploy/pptracking/python#%E5%8F%82%E6%95%B0%E8%AF%B4%E6%98%8E)

# %%
# !cd PaddleDetection && wget https://bj.bcebos.com/v1/paddledet/data/mot/demo/person.mp4 && wget https://bj.bcebos.com/v1/paddledet/data/mot/demo/entrance_count_demo.mp4
# 输出视频保存在output/person.mp4中
# !cd PaddleDetection && python deploy/pptracking/python/mot_jde_infer.py --model_dir=output_inference/fairmot_dla34_30e_1088x608 --video_file=person.mp4 --device=GPU
# !cd PaddleDetection && python deploy/pptracking/python/mot_jde_infer.py --model_dir=output_inference/fairmot_dla34_30e_1088x608 --do_entrance_counting --draw_center_traj --video_file=entrance_count_demo.mp4 --device=GPU
# Out:
# --2022-01-07 17:02:57--  https://bj.bcebos.com/v1/paddledet/data/mot/demo/person.mp4
# Resolving bj.bcebos.com (bj.bcebos.com)... 182.61.200.229, 182.61.200.195, 2409:8c04:1001:1002:0:ff:b001:368a
# Connecting to bj.bcebos.com (bj.bcebos.com)|182.61.200.229|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8850805 (8.4M) [video/mp4]
# Saving to: ‘person.mp4’
#
# person.mp4          100%[===================>]   8.44M  10.2MB/s    in 0.8s
#
# 2022-01-07 17:02:58 (10.2 MB/s) - ‘person.mp4’ saved [8850805/8850805]
#
# --2022-01-07 17:02:58--  https://bj.bcebos.com/v1/paddledet/data/mot/demo/entrance_count_demo.mp4
# Resolving bj.bcebos.com (bj.bcebos.com)... 182.61.200.229, 182.61.200.195, 2409:8c04:1001:1002:0:ff:b001:368a
# Connecting to bj.bcebos.com (bj.bcebos.com)|182.61.200.229|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6977441 (6.7M) [video/mp4]
# Saving to: ‘entrance_count_demo.mp4’
#
# entrance_count_demo 100%[===================>]   6.65M  4.71MB/s    in 1.4s
#
# 2022-01-07 17:03:00 (4.71 MB/s) - ‘entrance_count_demo.mp4’ saved [6977441/6977441]
#
# -----------  Running Arguments -----------
# batch_size: 1
# camera_id: -1
# cpu_threads: 1
# device: GPU
# do_entrance_counting: False
# draw_center_traj: False
# enable_mkldnn: False
# image_dir: None
# image_file: None
# model_dir: output_inference/fairmot_dla34_30e_1088x608
# mtmct_cfg: None
# mtmct_dir: None
# output_dir: output
# reid_batch_size: 50
# reid_model_dir: None
# run_benchmark: False
# run_mode: fluid
# save_images: False
# save_mot_txts: False
# scaled: False
# secs_interval: 2
# threshold: 0.5
# trt_calib_mode: False
# trt_max_shape: 1280
# trt_min_shape: 1
# trt_opt_shape: 640
# video_file: person.mp4
# ------------------------------------------
# -----------  Model Configuration -----------
# Model Arch: FairMOT
# Transform Order:
# --transform op: LetterBoxResize
# --transform op: NormalizeImage
# --transform op: Permute
# --------------------------------------------
# fps: 25, frame_count: 200
# Frame id: 1, Total count: 11
# detect frame: 1, fps: 0.357460
# Frame id: 2, Total count: 11
# detect frame: 2, fps: 0.694749
# Frame id: 3, Total count: 12
# detect frame: 3, fps: 1.016816
# Frame id: 4, Total count: 13
# detect frame: 4, fps: 1.323368
# Frame id: 5, Total count: 13
# detect frame: 5, fps: 1.618219
# Frame id: 6, Total count: 13
# detect frame: 6, fps: 1.900401
# Frame id: 7, Total count: 13
# detect frame: 7, fps: 2.170869
# Frame id: 8, Total count: 13
# Frame id: 53, Total count: 21
# detect frame: 53, fps: 15.016270
# Frame id: 54, Total count: 21
# detect frame: 54, fps: 14.984530
# Frame id: 55, Total count: 22
# detect frame: 55, fps: 14.960564
# Frame id: 56, Total count: 23
# detect frame: 56, fps: 14.911787
# Frame id: 57, Total count: 23
# detect frame: 57, fps: 14.888188
# Frame id: 58, Total count: 23
# detect frame: 58, fps: 14.886206
# Frame id: 59, Total count: 24
# detect frame: 59, fps: 14.901464
# Frame id: 60, Total count: 24
# detect frame: 60, fps: 14.922626
# Frame id: 61, Total count: 24
# detect frame: 61, fps: 14.926681
# Frame id: 62, Total count: 24
# detect frame: 62, fps: 14.941652
# Frame id: 63, Total count: 24
# detect frame: 63, fps: 14.940351
# Frame id: 64, Total count: 24
# detect frame: 64, fps: 14.923255
# Frame id: 65, Total count: 24
# detect frame: 65, fps: 14.919067
# Frame id: 66, Total count: 24
# detect frame: 66, fps: 14.921960
# Frame id: 67, Total count: 24
# detect frame: 67, fps: 14.932877
# Frame id: 68, Total count: 24
# detect frame: 68, fps: 14.933786
# Frame id: 69, Total count: 25
# detect frame: 69, fps: 14.919115
# Frame id: 70, Total count: 26
# detect frame: 70, fps: 14.898069
# Frame id: 71, Total count: 26
# detect frame: 71, fps: 14.878476
# Frame id: 72, Total count: 26
# detect frame: 72, fps: 14.863612
# Frame id: 73, Total count: 26
# detect frame: 73, fps: 14.847393
# Frame id: 74, Total count: 26
# detect frame: 74, fps: 14.838768
# Frame id: 75, Total count: 26
# detect frame: 75, fps: 14.857684
# Frame id: 76, Total count: 26
# detect frame: 76, fps: 14.901282
# Frame id: 77, Total count: 26
# detect frame: 77, fps: 14.925159
# Frame id: 78, Total count: 26
# detect frame: 78, fps: 14.926707
# Frame id: 79, Total count: 26
# detect frame: 79, fps: 14.933398
# Frame id: 80, Total count: 26
# detect frame: 80, fps: 14.926224
# Frame id: 81, Total count: 26
# detect frame: 81, fps: 14.921681
# Frame id: 82, Total count: 26
# detect frame: 82, fps: 14.915611
# Frame id: 83, Total count: 28
# detect frame: 83, fps: 14.921110
# Frame id: 84, Total count: 28
# detect frame: 84, fps: 14.924944
# Frame id: 85, Total count: 28
# detect frame: 85, fps: 14.925342
# Frame id: 86, Total count: 28
# detect frame: 86, fps: 14.894228
# Frame id: 87, Total count: 28
# detect frame: 87, fps: 14.890799
# Frame id: 88, Total count: 28
# detect frame: 88, fps: 14.899495
# Frame id: 89, Total count: 28
# detect frame: 89, fps: 14.897476
# Frame id: 90, Total count: 29
# detect frame: 90, fps: 14.834189
# Frame id: 91, Total count: 29
# detect frame: 91, fps: 14.835102
# Frame id: 92, Total count: 29
# detect frame: 92, fps: 14.841848
# Frame id: 93, Total count: 29
# detect frame: 93, fps: 14.842024
# Frame id: 94, Total count: 29
# detect frame: 94, fps: 14.878483
# Frame id: 95, Total count: 29
# detect frame: 95, fps: 14.884027
# Frame id: 96, Total count: 29
# detect frame: 96, fps: 14.890453
# Frame id: 97, Total count: 29
# detect frame: 97, fps: 14.900631
# Frame id: 98, Total count: 29
# detect frame: 98, fps: 14.911347
# Frame id: 99, Total count: 30
# detect frame: 99, fps: 14.906670
# Frame id: 100, Total count: 30, Count during 2 secs: 21
# detect frame: 100, fps: 14.914043
# Frame id: 101, Total count: 30
# detect frame: 101, fps: 14.916791
# Frame id: 102, Total count: 30
# detect frame: 102, fps: 14.912927
# Frame id: 103, Total count: 30
# detect frame: 103, fps: 14.910329
# Frame id: 104, Total count: 30
# detect frame: 104, fps: 14.916287
# Frame id: 105, Total count: 30
# detect frame: 105, fps: 14.892919
# Frame id: 106, Total count: 30
# detect frame: 106, fps: 14.922329
# Frame id: 107, Total count: 30
# detect frame: 107, fps: 14.904906
# Frame id: 108, Total count: 30
# detect frame: 108, fps: 14.890458
# Frame id: 109, Total count: 30
# detect frame: 109, fps: 14.906967
# Frame id: 110, Total count: 30
# detect frame: 110, fps: 14.984615
# Frame id: 111, Total count: 30
# detect frame: 111, fps: 14.990161
# Frame id: 112, Total count: 30
# detect frame: 112, fps: 14.983925
# Frame id: 113, Total count: 30
# detect frame: 113, fps: 14.978614
# Frame id: 114, Total count: 30
# detect frame: 114, fps: 14.971538
# Frame id: 115, Total count: 30
# detect frame: 115, fps: 14.973502
# Frame id: 116, Total count: 30
# detect frame: 116, fps: 14.958963
# Frame id: 117, Total count: 30
# detect frame: 117, fps: 14.935520
# Frame id: 118, Total count: 30
# detect frame: 118, fps: 14.916661
# Frame id: 119, Total count: 30
# detect frame: 119, fps: 14.913487
# Frame id: 120, Total count: 30
# detect frame: 120, fps: 14.907158
# Frame id: 121, Total count: 30
# detect frame: 121, fps: 14.910303
# Frame id: 122, Total count: 30
# detect frame: 122, fps: 14.920420
# Frame id: 123, Total count: 30
# detect frame: 123, fps: 14.928944
# Frame id: 124, Total count: 30
# detect frame: 124, fps: 14.944766
# Frame id: 125, Total count: 30
# detect frame: 125, fps: 14.977945
# Frame id: 126, Total count: 30
# detect frame: 126, fps: 14.983007
# Frame id: 127, Total count: 30
# detect frame: 127, fps: 14.998869
# Frame id: 128, Total count: 30
# detect frame: 128, fps: 15.007346
# Frame id: 129, Total count: 30
# detect frame: 129, fps: 14.998145
# Frame id: 130, Total count: 32
# detect frame: 130, fps: 14.982895
# Frame id: 131, Total count: 32
# detect frame: 131, fps: 14.975699
# Frame id: 132, Total count: 32
# detect frame: 132, fps: 14.984969
# Frame id: 133, Total count: 32
# detect frame: 133, fps: 14.994727
# Frame id: 134, Total count: 32
# detect frame: 134, fps: 14.998539
# Frame id: 135, Total count: 32
# detect frame: 135, fps: 14.998464
# Frame id: 136, Total count: 32
# detect frame: 136, fps: 15.005394
# Frame id: 137, Total count: 32
# detect frame: 137, fps: 15.020134
# Frame id: 138, Total count: 32
# detect frame: 138, fps: 15.018773
# Frame id: 139, Total count: 32
# detect frame: 139, fps: 15.023087
# Frame id: 140, Total count: 32
# detect frame: 140, fps: 15.038754
# Frame id: 141, Total count: 32
# detect frame: 141, fps: 15.045068
# Frame id: 142, Total count: 33
# Frame id: 187, Total count: 44
# detect frame: 187, fps: 14.716048
# Frame id: 188, Total count: 45
# detect frame: 188, fps: 14.730830
# Frame id: 189, Total count: 45
# detect frame: 189, fps: 14.730377
# Frame id: 190, Total count: 45
# detect frame: 190, fps: 14.745449
# Frame id: 191, Total count: 45
# detect frame: 191, fps: 14.761007
# Frame id: 192, Total count: 45
# detect frame: 192, fps: 14.757063
# Frame id: 193, Total count: 45
# detect frame: 193, fps: 14.757792
# Frame id: 194, Total count: 45
# detect frame: 194, fps: 14.777491
# Frame id: 195, Total count: 45
# detect frame: 195, fps: 14.783163
# Frame id: 196, Total count: 45
# detect frame: 196, fps: 14.726692
# Frame id: 197, Total count: 45
# detect frame: 197, fps: 14.744742
# Frame id: 198, Total count: 45
# detect frame: 198, fps: 14.751981
# Frame id: 199, Total count: 45
# detect frame: 199, fps: 14.771649
# Frame id: 200, Total count: 45, Count during 2 secs: 24
# detect frame: 200, fps: 14.773566
# -----------  Running Arguments -----------
# batch_size: 1
# camera_id: -1
# cpu_threads: 1
# device: GPU
# do_entrance_counting: True
# draw_center_traj: True
# enable_mkldnn: False
# image_dir: None
# image_file: None
# model_dir: output_inference/fairmot_dla34_30e_1088x608
# mtmct_cfg: None
# mtmct_dir: None
# output_dir: output
# reid_batch_size: 50
# reid_model_dir: None
# run_benchmark: False
# run_mode: fluid
# save_images: False
# save_mot_txts: False
# scaled: False
# secs_interval: 2
# threshold: 0.5
# trt_calib_mode: False
# trt_max_shape: 1280
# trt_min_shape: 1
# trt_opt_shape: 640
# video_file: entrance_count_demo.mp4
# ------------------------------------------
# -----------  Model Configuration -----------
# Model Arch: FairMOT
# Transform Order:
# --transform op: LetterBoxResize
# --transform op: NormalizeImage
# --transform op: Permute
# --------------------------------------------
# fps: 30, frame_count: 149
# Frame id: 1, Total count: 42, In count: 0, Out count: 0
# detect frame: 1, fps: 0.351226
# Frame id: 2, Total count: 42, In count: 0, Out count: 0
# detect frame: 2, fps: 0.681583
# Frame id: 3, Total count: 43, In count: 0, Out count: 0
# detect frame: 3, fps: 0.995046
# Frame id: 4, Total count: 43, In count: 0, Out count: 0
# detect frame: 4, fps: 1.292620
# Frame id: 5, Total count: 43, In count: 0, Out count: 0
# detect frame: 5, fps: 1.577045
# Frame id: 6, Total count: 44, In count: 0, Out count: 0
# detect frame: 6, fps: 1.849335
# Frame id: 7, Total count: 47, In count: 0, Out count: 0
# detect frame: 7, fps: 2.109342
# Frame id: 8, Total count: 47, In count: 0, Out count: 0
# detect frame: 8, fps: 2.356928
# Frame id: 9, Total count: 47, In count: 0, Out count: 0
# detect frame: 9, fps: 2.593962
# Frame id: 10, Total count: 47, In count: 0, Out count: 0
# detect frame: 10, fps: 2.821172
# Frame id: 11, Total count: 48, In count: 0, Out count: 0
# detect frame: 11, fps: 3.039070
# Frame id: 12, Total count: 48, In count: 0, Out count: 0
# detect frame: 12, fps: 3.247527
# Frame id: 13, Total count: 48, In count: 0, Out count: 0
# detect frame: 13, fps: 3.448729
# Frame id: 111, Total count: 74, In count: 0, Out count: 2
# detect frame: 111, fps: 13.188470
# Frame id: 112, Total count: 74, In count: 0, Out count: 2
# detect frame: 112, fps: 13.167952
# Frame id: 113, Total count: 74, In count: 0, Out count: 2
# detect frame: 113, fps: 13.195976
# Frame id: 114, Total count: 75, In count: 1, Out count: 2
# detect frame: 114, fps: 13.221244
# Frame id: 115, Total count: 75, In count: 1, Out count: 2
# detect frame: 115, fps: 13.247255
# Frame id: 116, Total count: 76, In count: 1, Out count: 2
# detect frame: 116, fps: 13.243891
# Frame id: 117, Total count: 76, In count: 2, Out count: 2
# detect frame: 117, fps: 13.255343
# Frame id: 118, Total count: 77, In count: 2, Out count: 2
# detect frame: 118, fps: 13.247696
# Frame id: 119, Total count: 77, In count: 2, Out count: 2
# detect frame: 119, fps: 13.258636
# Frame id: 120, Total count: 77, In count: 2, Out count: 2, Count during 2 secs: 58
# detect frame: 120, fps: 13.270840
# Frame id: 121, Total count: 78, In count: 2, Out count: 2
# detect frame: 121, fps: 13.298343
# Frame id: 122, Total count: 78, In count: 2, Out count: 2
# detect frame: 122, fps: 13.336339
# Frame id: 123, Total count: 78, In count: 2, Out count: 2
# detect frame: 123, fps: 13.396084
# Frame id: 124, Total count: 78, In count: 2, Out count: 2
# detect frame: 124, fps: 13.416938
# Frame id: 125, Total count: 78, In count: 2, Out count: 2
# detect frame: 125, fps: 13.427232
# Frame id: 126, Total count: 79, In count: 2, Out count: 2
# detect frame: 126, fps: 13.429925
# Frame id: 127, Total count: 79, In count: 2, Out count: 2
# detect frame: 127, fps: 13.405662
# Frame id: 128, Total count: 79, In count: 2, Out count: 2
# detect frame: 128, fps: 13.425970
# Frame id: 129, Total count: 79, In count: 2, Out count: 2
# detect frame: 129, fps: 13.395287
# Frame id: 130, Total count: 79, In count: 2, Out count: 2
# detect frame: 130, fps: 13.392883
# Frame id: 131, Total count: 79, In count: 2, Out count: 2
# detect frame: 131, fps: 13.397537
# Frame id: 132, Total count: 79, In count: 2, Out count: 2
# detect frame: 132, fps: 13.451504
# Frame id: 133, Total count: 79, In count: 2, Out count: 2
# detect frame: 133, fps: 13.444695
# Frame id: 134, Total count: 79, In count: 2, Out count: 2
# detect frame: 134, fps: 13.450251
# Frame id: 135, Total count: 80, In count: 2, Out count: 2
# detect frame: 135, fps: 13.458675
# Frame id: 136, Total count: 81, In count: 2, Out count: 2
# detect frame: 136, fps: 13.474745
# Frame id: 137, Total count: 81, In count: 2, Out count: 2
# detect frame: 137, fps: 13.481105

# %% [markdown]
# # MTMCT 跨镜跟踪体验
#
# 跨镜头多目标跟踪是对同一场景下的不同摄像头拍摄的视频进行多目标跟踪，是监控视频领域一个非常重要的研究课题。
#
# 相较于单镜头跟踪，跨镜跟踪将不同镜头获取到的跟踪轨迹进行融合，得到跨镜跟踪的输出轨迹。PP-Tracking选用DeepSORT方案实现跨镜跟踪，为了达到实时性选用了PaddleDetection自研的PP-YOLOv2和PP-PicoDet作为检测器，选用PaddleClas自研的轻量级网络PP-LCNet作为ReID模型。更多内容可参考[文档](https://github.com/PaddlePaddle/PaddleDetection/tree/develop/configs/mot/mtmct)
#
# 本项目展示城市主干道场景下的车辆跨镜跟踪预测流程，数据来自[AIC21](https://www.aicitychallenge.org/)开源数据集

# %% [markdown]
# # Step 1
# #### 下载预测部署模型
#
# 首先我们下载目标检测和ReID预测模型，[下载地址](https://github.com/PaddlePaddle/PaddleDetection/tree/develop/configs/mot/mtmct#deepsort%E5%9C%A8-aic21-mtmctcityflow-%E8%BD%A6%E8%BE%86%E8%B7%A8%E5%A2%83%E8%B7%9F%E8%B8%AA%E6%95%B0%E6%8D%AE%E9%9B%86test%E9%9B%86%E4%B8%8A%E7%9A%84%E7%BB%93%E6%9E%9C)，然后统一放在`~/PaddleDetection/output_inference`下

# %%
# !wget https://paddledet.bj.bcebos.com/models/mot/deepsort/ppyolov2_r50vd_dcn_365e_aic21mtmct_vehicle.tar
# !wget https://paddledet.bj.bcebos.com/models/mot/deepsort/deepsort_pplcnet_vehicle.tar
# !cd ~/PaddleDetection/ && mkdir -p output_inference
# !mv ppyolov2_r50vd_dcn_365e_aic21mtmct_vehicle.tar ~/PaddleDetection/output_inference
# !mv deepsort_pplcnet_vehicle.tar ~/PaddleDetection/output_inference
# !cd ~/PaddleDetection/output_inference && tar -xvf ppyolov2_r50vd_dcn_365e_aic21mtmct_vehicle.tar && tar -xvf deepsort_pplcnet_vehicle.tar

# %% [markdown]
# # Step 2
# #### 跨镜跟踪预测
#
# 在完成模型下载后，需要修改`PaddleDetection/deploy/pptracking/python`路径下的`mtmct_cfg.yml`，这份配置文件中包含了跨镜跟踪中轨迹融合的相关参数。首先需要确定`cameras_bias`中对应的名称与输入视频名称对应；其次，我们本次项目使用轨迹融合中的通用方法，将zone和camera相关的方法设置为False。修改后配置如下：
#
# ```
# # config for MTMCT
# MTMCT: True
# cameras_bias:
#   c003: 0
#   c004: 0
# # 1.zone releated parameters
# use_zone: False #True
# zone_path: dataset/mot/aic21mtmct_vehicle/S06/zone
# # 2.tricks parameters, can be used for other mtmct dataset
# use_ff: True
# use_rerank: True
# # 3.camera releated parameters
# use_camera: False #True
# use_st_filter: False
# # 4.zone releated parameters
# use_roi: False #True
# roi_dir: dataset/mot/aic21mtmct_vehicle/S06
# ```
#
#
# 配置完成后即可运行如下命令，输入视频为c003.mp4和c004.mp4两个不同视角的摄像头拍摄结果，跨镜跟踪输出视频保存在

# %%
# !wget https://bj.bcebos.com/v1/paddledet/data/mot/demo/mtmct-demo.tar && mv mtmct-demo.tar ~/PaddleDetection && cd ~/PaddleDetection && tar xvf mtmct-demo.tar 
# !cd ~/PaddleDetection && python deploy/pptracking/python/mot_sde_infer.py --model_dir=output_inference/ppyolov2_r50vd_dcn_365e_aic21mtmct_vehicle/ --reid_model_dir=output_inference/deepsort_pplcnet_vehicle/ --mtmct_dir=./mtmct-demo --device=GPU --mtmct_cfg=deploy/pptracking/python/mtmct_cfg.yml --scaled=True --save_mot_txts --save_images
